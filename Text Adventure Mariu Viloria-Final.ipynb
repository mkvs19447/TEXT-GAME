# %%
"""
Copy improved November 2021

@author: Mariu Viloria.
"""

"""
DocString:

This game is based on some scenes from the movie JUMANJI (1995).
The movie consists in a magic board game were players go through different
challenges and the main idea is to survive and reach the end of the game.

Known bugs:
---

Changes made:
* Impovement of comments
* 'in' syntax included 
* 'prompt=' argument included in all users imputs

"""

#import libraries we will use

from sys import exit
import random
import pandas

#defining first function with the Introduction of the game to start the game.

def start():
    #declare object
    name= input(prompt= " \033[1mWelcome!, Please enter your name\033[0m \n\n")   
   #Capitalizing te users input
    name=name.capitalize() 
   
    #function will print the following introduction when called
    print(f""" \t\t WELCOME!!! {name} you are just about to start a great adventure!. \n
      \t\t\t \n INTRODUCTION:\n
      \t\t\t You recently moved into an old mansion in New Hampshire,\n
      \t\t\t it has been abandoned for more than 26 years... On your first\n
      \t\t\t night you start listening to a Drumming sound coming from the attic...\n
      \t\t\t You go search what's making this sound, and find out its coming\n
      \t\t\t out of a board game named\n\n
  888888 888     888 888b     d888        d8888 888b    888   888888 8888888 
    "88b 888     888 8888b   d8888       d88888 8888b   888     "88b   888   
     888 888     888 88888b.d88888      d88P888 88888b  888      888   888   
     888 888     888 888Y88888P888     d88P 888 888Y88b 888      888   888   
     888 888     888 888 Y888P 888    d88P  888 888 Y88b888      888   888   
     888 888     888 888  Y8P  888   d88P   888 888  Y88888      888   888   
     88P Y88b. .d88P 888   "   888  d8888888888 888   Y8888      88P   888   
     888  "Y88888P"  888       888 d88P     888 888    Y888      888 8888888 
   .d88P                                                       .d88P         
 .d88P"                                                      .d88P"          
888P"                                                       888P"            
\n
      \t\t\t Brave enough you want to give it a try...\n\n
      \t\t\n""")       

    input(prompt=" \033[1mPress to continue\033[0m \n")
    scene1()  #calls next function 

#define function with scene 1
def scene1():   
    
    #decorations to separate each scene, scene 1 requires to answer correctly 
    #to move forward, it will keep on displaying the scene until user gets it 
    #right
    
    print("""\t\t 
╔═╗╔═╗╦═╗╔╦╗  ╦
╠═╝╠═╣╠╦╝ ║   ║
╩  ╩ ╩╩╚═ ╩   ╩
 \n
      \t\t Roll the dice... the magic begins... \n
      \t\t Let's see if you guess what this is:\n\n
      \t\t\t \033[1m'I tiny bite can make you itch, make you sneeze, make you twitch'\033[0m \n""")
   
    print("""\t1. Spiders \n
      \t2. Mosquitos\n
      \t3. Ants\n\n """) 

    #user has to input their choice, 
    choice= input(prompt="""\033[1mMake your choice\033[0m\n""")
    choice= choice.lower() #turn input to lower case
    
    #conditionals for choices
    if "1" in choice or "spider" in choice:
        print("\n\n\tNot spiders, but good guess.\n"
        "Try again, let's see what you get.\n")
        #return player to scene1
        scene1() 
    
    
    elif "2" in choice or "mosquito" in choice:
        print("\t\n\n\033[1mThat's it, you are right... Time to fight them out\n"
              "and roll the dice\033[0m\n")
        #sends player to next part
        scene2()   
            
    elif "3" in choice or "ant" in choice:
        print("\n\n\tNot Ants, but good guess.\n"
                       "Try again, let's see what you get.\n")
        #sends player back to the beginning of the scene
        scene1()  
                
    else:
        print("\n\nInvalid Command. Try again.")
        input(prompt=" \033[1mPress to continue\033[0m \n")
        #sends player back to the beginning of the scene
        scene1() 
    

#scene 2 definition, user has 2 chances to answer correctly, if not Fail 
#function is called and game ends. Decoration to separate contents.

def scene2():
    #define objects, list to choose from and a counter starter
    chest= ['Scissor', 'Knife', 'Saw','Lawnmower','Sword'] 
    chance= 2 
    
    print("""\n\n\n\t\t 
╔═╗╔═╗╦═╗╔╦╗  ╦╦
╠═╝╠═╣╠╦╝ ║   ║║
╩  ╩ ╩╩╚═ ╩   ╩╩
\n
           Roll the dice again and the magic board reads:
           \033[1m'They grow much faster than bamboo, take care or they'll come
           after you.\033[0m\n\n\n
           Now branches are coming out of everywhere...
           
           THEY GOT YOU ON YOUR FEET... YOU NEED TO SCAPE!!!\n\n
           
           There is a chest with some items, choose the best to free
           yourself... But be aware you only have 2 chances.
           
           """ )
    #show user what's in the chest
    print(chest) 
    
    input(prompt="\nPress enter to continue")    
   
    #Loop to discount chances when chance variable = 0 is fail.
    
    while chance > 0:
            
        answer=  input(prompt= """ \n\nMake your choice \n""")
        answer= answer.lower()
        
        if "scissor" in answer or '1' in answer: 
            #chance -= 1
            print(f"""\nReally? Scissors are for paper.... \n""")
            chance -= 1
            
                
        elif "knife" in answer or '2' in answer:
            print(f"""\nKnife? Are you going to cook these branches??... 
                      \n""")
            chance -= 1
            
    
        elif "saw" in answer or '3' in answer:
            print(f"""\nIt would work... But it's not the case. """)
            chance -= 1
            
        
        elif "lawnmower" in answer or '4' in answer or "lawn" in answer:
            print(f"""\nNot the typical item in a chest.\n""")
            chance -= 1
            
#correct answer send player to next scene            
        elif "sword" in answer or '5' in answer:
            print(f"""\nYES... The Sword will cut this branch.\n
                 
╦ ╦┌─┐┬ ┬  ┌─┐┬─┐┌─┐  ┌─┐┬─┐┌─┐┌─┐┬
╚╦╝│ ││ │  ├─┤├┬┘├┤   ├┤ ├┬┘├┤ ├┤ │
 ╩ └─┘└─┘  ┴ ┴┴└─└─┘  └  ┴└─└─┘└─┘o
""")    
            scene3()    
        else: 
            print(f"""\nAre you are trying to fool me? \n""")
            chance -= 1
        
#After 2 wrong chances, user fails. Game over.                
    if chance == 0:
        print(f"""\nOh no... you've missed two chances... The Branch Eats you""")
        fail()  

            
#Final scene, not in the movie, just displaying random questions and
#any answer will work. Its been hard to survive until this point. User deserves.

def scene3():
    
    #declare objects, a list to include random questions and a counter
    q_lst= ["How much is 3*3*3 ?",
                     "What is the first name of Jumanji (1995) main actor?",
                     "COMPLETE: O'er the land of the free and the home of the_??",
                     "How much is 10*2+2?",
                     "What's your favorite season?"]
    
    questions=3
    
    print(f"""
╔═╗╔═╗╦═╗╔╦╗  ╦╦╦
╠═╝╠═╣╠╦╝ ║   ║║║
╩  ╩ ╩╩╚═ ╩   ╩╩╩
\n\t\t Ok, you've reached the last challenge of this game\n
       to complete the game successfully you need to think fast to answer 3\n 
       simple questions on time\n""")
    
    #Loops to choose random questions from a list
    
    while questions > 0:
    
        #use choice method to randomly select question
        question = random.choice(q_lst) 
        input(prompt="\n\nPress enter for your question\n")
        print(question)

        #Conditionals for questions 
        if question == q_lst[0]:
            print("\nGotta answer only Integers")
            mult = input(prompt="""\n   """)
            
            #code expects an integer, if input diferent than integer, then print
            #each try will decrease count by one
            #string imputs are turned to lower case to avoid bugs
            #each try wil decrease counter by 1
            if mult== 27:                   
                print("\nThat was fast\n")
            elif type(mult)!= int:   
                print("I was expecting an Integer input")
            else:                          
                print(f"""\nWRONG! Need to practice\n""") 
            questions -=1    
        
        elif question== q_lst[1]:
            print("\nHint: Was a funny guy")
            
            actor = input(prompt="""\n    """)
            actor = actor.lower()   
            
            if 'robin' in actor or 'robbin' in actor \
            or 'robie' in actor or 'robbi' in actor :
                print("\nYou are right, sad he died.\n")         
            
            else:
                print(f"""\nHuh??? Not for this movie!\n""")
            questions -=1

        elif question == q_lst[2]:
            print("\nThink fast\n")
            
            answ = input(prompt="""\n    """)
            answ = answ.lower()
            
            if 'brave' in answ or 'brabe' in answ:
                print("\nI love this frase!!\n")         
            
            else:
                print(f"""\nCommon is a very popular National Anthem!\n""")
            questions -=1
                
        
        elif question == q_lst[3]:
            print("\nAnswer only Integers")
            
            sum_m = input(prompt="""\n    """)
            
            if '22' in sum_m:
                print("\nGood Math skills\n")         
            elif type(sum_m)!= int:
                print("I was expecting an Integer input")
            else:
                print(f"""\nGotta practice some math!""")
            questions -=1
            
        elif question == q_lst[4]:
            
            print("\nBonus question. Just input something")
            season = input(prompt="""\n    """)
            
            print('\nMine is Autumn\n')    
            questions -=1 
# when counter reaches 0 its the end of the game and the player wins   
    if questions==0:
        print("""\n\n ANYWAY YOU'VE MADE IT UNTIL THE END!!!\n
██╗    ██╗██╗███╗   ██╗███╗   ██╗███████╗██████╗ ██╗
██║    ██║██║████╗  ██║████╗  ██║██╔════╝██╔══██╗██║
██║ █╗ ██║██║██╔██╗ ██║██╔██╗ ██║█████╗  ██████╔╝██║
██║███╗██║██║██║╚██╗██║██║╚██╗██║██╔══╝  ██╔══██╗╚═╝
╚███╔███╔╝██║██║ ╚████║██║ ╚████║███████╗██║  ██║██╗
 ╚══╝╚══╝ ╚═╝╚═╝  ╚═══╝╚═╝  ╚═══╝╚══════╝╚═╝  ╚═╝╚═╝
                                                    
\n""")


    exit()  
    #scene3()

#Last function defined is the fail function. 
#Prints decorations to look like a game and exits the game
def fail():
    print(f"""You've failed""")
    print(f"""\t\t\t\t
 ██████╗  █████╗ ███╗   ███╗███████╗     ██████╗ ██╗   ██╗███████╗██████╗ 
██╔════╝ ██╔══██╗████╗ ████║██╔════╝    ██╔═══██╗██║   ██║██╔════╝██╔══██╗
██║  ███╗███████║██╔████╔██║█████╗      ██║   ██║██║   ██║█████╗  ██████╔╝
██║   ██║██╔══██║██║╚██╔╝██║██╔══╝      ██║   ██║╚██╗ ██╔╝██╔══╝  ██╔══██╗
╚██████╔╝██║  ██║██║ ╚═╝ ██║███████╗    ╚██████╔╝ ╚████╔╝ ███████╗██║  ██║
 ╚═════╝ ╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝     ╚═════╝   ╚═══╝  ╚══════╝╚═╝  ╚═╝
                                                                          
\n""")
    
    input(prompt="""\nPress any key to exit""")

                  
start()
# Out:
#  Welcome!, Please enter your name
#
# MARIU
#  		 WELCOME!!! Mariu you are just about to start a great adventure!.
#
#
#  INTRODUCTION:
#
#       			 You recently moved into an old mansion in New Hampshire,
#
#       			 it has been abandoned for more than 26 years... On your first
#
#       			 night you start listening to a Drumming sound coming from the attic...
#
#       			 You go search what's making this sound, and find out its coming
#
#       			 out of a board game named
#
#
#   888888 888     888 888b     d888        d8888 888b    888   888888 8888888
#     "88b 888     888 8888b   d8888       d88888 8888b   888     "88b   888
#      888 888     888 88888b.d88888      d88P888 88888b  888      888   888
#      888 888     888 888Y88888P888     d88P 888 888Y88b 888      888   888
#      888 888     888 888 Y888P 888    d88P  888 888 Y88b888      888   888
#      888 888     888 888  Y8P  888   d88P   888 888  Y88888      888   888
# ...
